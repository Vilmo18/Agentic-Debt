# %%
import pickle

with open('GoldMiner_DefaultOrganization_20250923182344.pkl', 'rb') as file:
    my_data = pickle.load(file)

print(my_data)
# Out:
# [{'turn_index': 0, 'timestamp': '2025-23-09 18:26:14', 'phase': 'Coding', 'role': 'Programmer', 'interlocutor': 'Chief Technology Officer', 'turn_number': 0, 'files_changed': ['index.html', 'level.py', 'main.py', 'models.py'], 'files': {'main.py': '\'\'\'\n\nMain entry for the Gold Miner web game using PyScript (Python in the browser).\nCoordinates the game loop, user input, rendering, and level flow.\n\nTo run:\n- Open index.html in a browser with internet access to load PyScript.\n- The game runs fully client-side in the browser.\n\nControls:\n- Press Space or click to release the claw to grab objects.\n- Meet or exceed the goal before time runs out to advance to the next level.\n\n\'\'\'\n\nfrom js import document, window\nfrom pyodide.ffi import create_proxy\nimport math\nimport random\nfrom models import Claw, MineObject, distance\nfrom level import LevelManager\n\n\nclass Game:\n    def __init__(self):\n        # Canvas and drawing context\n        self.canvas = document.getEle
# ...

# %%
my_data
# Out:
# [{'turn_index': 0,
#   'timestamp': '2025-23-09 18:26:14',
#   'phase': 'Coding',
#   'role': 'Programmer',
#   'interlocutor': 'Chief Technology Officer',
#   'turn_number': 0,
#   'files_changed': ['index.html', 'level.py', 'main.py', 'models.py'],
# ...
